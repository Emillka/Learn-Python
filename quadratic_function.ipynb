# %% [markdown]
# <a href="https://colab.research.google.com/github/Emillka/Python_learn_projects/blob/main/quadratic_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

class FunkcjaKwadratowa:

    def __init__(self,a,b,c):
        self.a = a
        self.b = b
        self.c = c

    def make_function(self):
        print( f'{self.a}* x ** 2 + {self.b} * x + {self.c}')

    def rozwiaz(self):
        if self.a == 0 and self.b == 0 and self.c ==0:
            print('Równanie tożsamosciowe.')
        elif self.a == 0 and self.b == 0 and self.c != 0:
                print('Równanie sprzeczne.')
        elif self.a == 0 and self.b != 0 :
            x = - self.c / self.b
            print(x)
        elif self.a != 0:
            delta = self.b ** 2 - 4 * self.a * self.c
            if delta >0:
                sqrt_delta = np.sqrt(delta)
                x1 = (-self.b -sqrt_delta) / (2*self.a)
                x2 = (-self.b + sqrt_delta) / (2* self.a)
                print(x1,x2)
            elif delta == 0:
                x = -self.b / (2* self.a)
                print(x)
            else:
                print('Brak rozwiązania')
        else:
            raise Error



# %% Test
fk = FunkcjaKwadratowa(3,1,-4)
fk.make_function()
fk.rozwiaz()

def main():
    for i in range(100):
        a=np.random.choice(range(-100,100))
        b=np.random.choice(range(-100,100))
        c=np.random.choice(range(-100,100))

        fun = FunkcjaKwadratowa(a, b, c)
        fun.rozwiaz()
if __name__ == '__main__':
    main()
# Out:
# 3* x ** 2 + 1 * x + -4
# -1.3333333333333333 1.0
# -0.8269365500832143 2.466936550083214
# Brak rozwiązania
# Brak rozwiązania
# -4.363636363636363 0.0
# 0.5810201630691916 -0.9483671018447017
# -0.8696993145240461 0.5988659811907128
# 0.1473896004195019 -1.1605474951563441
# Brak rozwiązania
# Brak rozwiązania
# Brak rozwiązania
# -1.1861406616345072 1.6861406616345072
# -2.3133655519841816 0.051460790079419706
# -2.1498670934582806 0.6252769295238545
# Brak rozwiązania
# Brak rozwiązania
# Brak rozwiązania
# -1.150360383651325 2.4836937169846585
# Brak rozwiązania
# 0.4800584781572863 -2.0073312054300136
# 1.3465794383301521 -0.6914070245370487
# -1.5287399091060314 0.4642237800737734
# 1.081378416912296 -1.0480450835789625
# -6.306546117437511 -0.40773959684820327
# -1.5616067615350862 0.5289980658829123
# Brak rozwiązania
# 0.17979667351641193 -2.9445025558693527
# 0.1526578176052604 -2.396560256629651
# -1.1094757082487299 0.7761423749153966
# 1.1208260326843935 -1.25718966904803
# -1.1160295334594519 0.7867612407765251
# 0.42857142857142855 -1.4615384615384615
# Brak rozwiązania
# Brak rozwiązania
# Brak rozwiązania
# -0.14496003168526014 -2.2994844127591842
# 2.101877731077794 -0.50613305022673
# Brak rozwiązania
# 2.053500597796817 -0.26562180991802925
# Brak rozwiązania
# Brak rozwiązania
# -0.38939848711552055 2.6393984871155203
# 2.7350865587104383 0.0830952594713798
# Brak rozwiązania
# Brak rozwiązania
# Brak rozwiązania
# Brak rozwiązania
# 2.590315066690848 -0.7392512369036138
# -1.2400640313073583 0.20160249284581974
# Brak rozwiązania
# -1.0452259909694313 1.0568538979461755
# Brak rozwiązania
# 0.28142024435298196 1.0564175934848559
# -1.908599573193253 -5.646955982362303
# Brak rozwiązania
# Brak rozwiązania
# 0.4655740640443828 4.534425935955617
# -3.176397286691976 1.3192544295491184
# -0.25210556923066757 0.09118602900078251
# Brak rozwiązania
# -0.7601287088420198 0.6212398199531308
# 0.21198997265216837 -1.0339077808713464
# -0.7542812707978059 -0.1152839465934985
# 0.08357406253664088 -0.4056079608417256
# -1.5194215270826428 0.925218628531918
# -0.8140953776893579 1.0918731554671357
# -1.2091632007754265 0.5129606691298568
# 1.3870967741935485
# 1.1858241320807286 -0.9073431194225007
# 1.134546602283232 -0.58135511292153
# Brak rozwiązania
# -2.2376452660833714 0.8505484918898228
# Brak rozwiązania
# 0.5755346508667722 -0.758633242416068
# Brak rozwiązania
# Brak rozwiązania
# -0.3566118917732969 3.2876463745319175
# -5.640305036908184 0.3545907511938979
# -2.0874342087037916 0.28743420870379166
# -0.3384615384615385
# Brak rozwiązania
# -0.397022561935204 2.158927323839966
# 0.7369537040117886 -2.9134242922470825
# Brak rozwiązania
# -0.5256032642204637 1.452875991493191
# 0.7612940604716703 -1.0946273938050035
# Brak rozwiązania
# -0.1058160057313745 -0.904822292140966
# -0.09049548320802785 19.890495483208028
# 1.4456733391658487 -5.731387624880134
# Brak rozwiązania
# 0.3374824603928641 2.3932867703763665
# Brak rozwiązania
# Brak rozwiązania
# Brak rozwiązania
# Brak rozwiązania
# -1.1469783146623818 1.783341951026018
# Brak rozwiązania
# Brak rozwiązania
# Brak rozwiązania
# Brak rozwiązania
